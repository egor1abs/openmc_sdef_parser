# %%
import openmc_sdef_parser as parse
from openmc_sdef_parser import plot_source

# %%
source_test = parse.make_openmc_source('./data/sdef_template.i', exclude_first=True, normalize=False)
# Out:
# Read finished

# %%
plot_source(source_test, interpolation=None, intensity_norm=True)

# %%
source_test.space.mesh
# Out:
# CylindricalMesh
# 	ID             =	2
# 	Name           =
# 	Dimensions     =	3
# 	Origin         =	[0. 0. 0.]
# 	N R pnts:      =	24
# 	R Min:         =	0.0
# 	R Max:         =	92.0
# 	N Phi pnts:    =	2
# 	Phi Min:       =	0.0
# 	Phi Max:       =	6.283185307179586
# 	N Z pnts:      =	36
# 	Z Min:         =	0.0
# 	Z Max:         =	140.0

# %%
import openmc

settings = openmc.Settings()
settings.source = source_test
